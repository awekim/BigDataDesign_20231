# %% [markdown]
# # Weekly Report
# - Team members: 21700365 Son Juchan, 21700411 Ahn Dongsu, 22000176 Kim Jimin
# - Meeting Date: 2023.06.05
# - Project Name: Big Data Capstone Design
# - Project Goal: Capstone Topic Selection and Proposal Writing

# %% [markdown]
# ### Weekly plan
#
# | Week    | Schedule        | Note                      |
# |---------|-----------------|---------------------------|
# | Week 9  | 2023.04.27<br>Topic selection and clarification | Presentation of individual interest topics |
# | Week 10 | 2023.05.03 <br> Data search and exploration  | Selection Topic: <b>Analysis of Disaster Vulnerable Areas<b>    |
# | Week 11 | 2023.05.10 <br> 문헌조사 |지민 : 논문조사, 김정현 교수님 미팅 <br>  동수 : 논문조사, 김정현 교수님 미팅 , 차별화에 대해 고민  <br> 주찬 : 논문조사 |
# | Week 12 | 2023.05.17 <br> 산불 취약지역에 대한 조사 |   동수, 지민 : 선행연구 및 사례 조사 <br> 주찬 : 기존 산불취약지도 분석    |
# | Week 13 | 2023.05.20 <br> 추가 변수 조사 | 동수:소방인프라시설 조사<br>주찬: 도로교통 데이터 조사<br>지민:인구특성 조사        |
# | Week 14 | 2023.05.27 <br>  방법론 심화 | XGBoost를 중점으로 조사           |
# | Week 15 | 2023.06.08  <br> Presentation preparation|        |
# | Week 16 | 2023.06.16  <br> Final presentation|      |

# %% [markdown]
# ---

# %% [markdown]
# ### Summary of previous meeting
# - Previous discussion: 산출결과 및 방법론에 대한 회의
#
# - Comments from Professor: 어떤 데이터를 가지고, 어떤 방법론을 가지고, 어떤 결과를 도출할 것인지에 대한 구체적인 계획이 필요함
#
# - Previous plan: 분석 구체화, 변수 추가, 방법론 심화

# %% [markdown]
# ---

# %% [markdown]
# ### Summary of working progress

# %% [markdown]
# ### 프로젝트 계획 개요
# 1. 모델링 <br>
#    1. XGBoost: XGBoost is a gradient-boosting algorithm that combines weak learner predictions to get stronger learner predictions. This aspect has been frequently used by data scientists in research lately for better results. In the XGBoost algorithm, CART acts as the base classifier. The input sample of the following decision tree and the training and prediction results of the previous decision tree are associated with each other and decided jointly.
#    2. Gradient Boosting Machine (GBM): In GBMs, the learning system is concerned with sequentially fitting new models to ensure that the resulting response variable is a more accurate estimate. The main goal of the algorithm is to construct new base learners in such a way that they are maximally correlated with the negative gradient of the ensemble-related loss function. In this aspect, GBMs have a significant record of success both in practical applications and in various machine learning and data mining challenges.
#    3. Light Gradient Boosting Machine (Light GBM). LightGBM is a kind of gradient boosting decision tree. This algorithm is mainly utilized in classification, sorting, and regression. LightGBM uses a histogram-based algorithm to increase computational speed and reduce complexity. It supports algorithms such as GBM, GBDT, GBRT, and MART, and its accuracy and efficiency are high. In LightGBM, gradient-based one-side sampling (GOSS) is one of the methods used to calculate information gain, so that less-trained instances contribute more to information gain. With these aspects, Light GBM provides quick practice and more extensive performance, low memory usage, good accuracy, support of GPU learning, and capacity to process large-scale data.<br><br>
#    한국 사례에 적용해서 더 좋은 모델을 선택할 예정<br><br>
#    출처: Wildfire Susceptibility Mapping Using Five Boosting Machine Learning Algorithms: The Case Study of the Mediterranean Region of Turkey<br><br>
#
# 2. 사용 변수
#
# ![image-3.png](attachment:image-3.png)
#
#
# 3. Output <br>
# 국가화재정보 시스템
# https://www.nfds.go.kr/stat/general.do
#
#
#
# ![image-2.png](attachment:image-2.png)
#
# 인명피해, 피해액 예측

# %% [markdown]
# #### 문제점
# 1. 도로변수 관련로만 피해액과 인명피해를 예측하기에는 논리가 부족함
# 2. 산림 인접 지역 도로를 선정해야 함
# 3. 산불 발생 발원지를 설정해야 하는지에 대한 문제
# 4. 도로가 없는 구역에 대한 문제

# %% [markdown]
# ---

# %% [markdown]
# ### Pending assignments or requests
